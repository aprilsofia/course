# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-30,30,1000)
y=x**2+2

# %%
plt.plot(x,y)

# %%
π=np.pi
θ=np.linspace(0, 2*π, 3000)

# %%
r=5
x = r * np.cos(θ)**2
y = r * np.sin(θ)

# %%
plt.plot(x, y,'r')

# %%
r=3
x=r*np.cos(θ)
y=r*np.sin(θ)

# %%
plt.plot(x,y,'y')

# %%
r=3
x=r*np.cos(θ)
y=r*np.sin(θ)

A=x/3
B=y/3

# %%
plt.xkcd()

# %% [raw]
# plt.plot(x, y)
#
# plt.plot(A, B)

# %% [markdown]
# # $$今天吃甚麼?$$

# %% [markdown]
# 總是不知道等一下用餐時間要吃什麼嗎?

# %% [markdown]
# 別擔心，只要輸入任一數字，神奇小精靈就會提供您最佳建議喔!

# %%
n=input ('請輸入任一數字:')
# Out:
# 請輸入任一數字:1

# %%
n=random
